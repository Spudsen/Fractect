# %%
from os import path, makedirs, walk
import pandas as pd
from shutil import copyfile
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Input, Rescaling
from keras.backend import clear_session
from keras.utils import image_dataset_from_directory
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from keras.metrics import BinaryAccuracy
from keras.callbacks import EarlyStopping
from random import choice

# %%
BATCH_SIZE =32
DATASET_NAMES = ('train','valid','test')
CLASS_DIRECTORY_NAMES = ('class_fracture','class_no_fracture')
DATASET_DIRECTORY = 'dataset'
TOP_DIRECTORY_CLASSIFIFICATIONS = path.join(DATASET_DIRECTORY ,'categorised_images')

#Hyperparameters
OPTIMIZER = Adam
LOSS_FUNCTION = BinaryCrossentropy
METRICS = [BinaryAccuracy(name='accuracy')]
EPOCHS = 50
BATCH_SIZE = 32
VERBOSE = 2
REGULARIZER='l2'
NUMBER_OF_CLASSES = 2
INPUT_SHAPE = (256,256,1)

# %%
def categorise_images(a_dataset_name):
    #creates a directory structure  like: images/
    #                                       class0/*.jpg
    #                                       class1/*.jpg
    #and copies the images into either leaf directory depending on their class label
    #this puts the data into a format that keras can load into a dataset

    fracture_directory = path.join(TOP_DIRECTORY_CLASSIFIFICATIONS, a_dataset_name,CLASS_DIRECTORY_NAMES[0])
    print('fracture_directory', fracture_directory)
    no_fracture_directory = path.join(TOP_DIRECTORY_CLASSIFIFICATIONS,a_dataset_name,CLASS_DIRECTORY_NAMES[-1])
    print('no_fracture_directory', no_fracture_directory)

    if path.exists(fracture_directory) == False:  
        makedirs(fracture_directory) 
    if path.exists(no_fracture_directory) == False:  
        makedirs(no_fracture_directory) 

    #read labels into pandas df
    csv_filepath = path.join(DATASET_DIRECTORY, a_dataset_name, 'labels/labels.csv')
    print('csv_filepath', csv_filepath)
    df = pd.read_csv(path.join(csv_filepath))
    df = df.set_index('filename')

    #walk through files and copy file to relevant directory
    images_dir = path.join(DATASET_DIRECTORY,a_dataset_name,'images')
    print('images_dir', images_dir)
    filenames = []
    for (dirpath, dirnames, filenames) in walk(images_dir):
        filenames.extend(filenames)
 
    for filename in filenames:
        #ignore mac os system file
        if filename.endswith('.DS_Store'):
            pass
        elif df.loc[filename]['target'] == 1:
            destination = path.join(fracture_directory, filename)
        else:
            destination = path.join(no_fracture_directory, filename)
        source = path.join(images_dir, filename)
        copyfile(source, destination)

# %%
for dataset_name in DATASET_NAMES:
    categorise_images(dataset_name)
# Out:
# fracture_directory dataset/categorised_images/train/class_fracture
# no_fracture_directory dataset/categorised_images/train/class_no_fracture
# csv_filepath dataset/train/labels/labels.csv
# images_dir dataset/train/images
# fracture_directory dataset/categorised_images/valid/class_fracture
# no_fracture_directory dataset/categorised_images/valid/class_no_fracture
# csv_filepath dataset/valid/labels/labels.csv
# images_dir dataset/valid/images
# fracture_directory dataset/categorised_images/test/class_fracture
# no_fracture_directory dataset/categorised_images/test/class_no_fracture
# csv_filepath dataset/test/labels/labels.csv
# images_dir dataset/test/images

# %%
def load_images(dataset_name):
    
    return image_dataset_from_directory(
    directory= path.join(TOP_DIRECTORY_CLASSIFIFICATIONS, dataset_name),
    labels='inferred',
    label_mode="binary",
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    image_size=(256, 256),
    shuffle=True,
    seed=42,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False
)

# %%
train_ds= load_images('train')
test_ds = load_images('test')
valid_ds = load_images('valid')
# Out:
# Found 3631 files belonging to 2 classes.
# Found 169 files belonging to 2 classes.
# Found 348 files belonging to 2 classes.

# %%
combined_train_ds = train_ds.concatenate(valid_ds)

# %%
training_images = []
training_labels = []
for images, labels in combined_train_ds.as_numpy_iterator():
    training_images.extend(images)
    training_labels.extend(labels)
training_images = np.array(training_images).astype('float32')/255
training_labels = np.array(training_labels).astype('int')
# Out:
# 2024-03-18 18:59:10.555796: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
random_training_image = choice(training_images)
plt.imshow(random_training_image, cmap='gray')
plt.show()

# %%
def create_model(input_shape):

    #create a Sequential  model
    model = Sequential()

    #Add the layers
    model.add(Input(input_shape))
    #Add 2 convolutional layers paired with max pooling layers
    model.add(Conv2D(filters = 64, kernel_size = (3,3), strides = (1,1), padding = 'valid', activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Conv2D(filters = 128, kernel_size = (3,3), strides = (1,1), padding = 'valid', activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
   
    #Flatten the output so that it can be processed as a Vector by the subsequnet Dense layer
    model.add(Flatten())

    #add a fully connected layer with  64 neurons and a relu activation function ouput shape = 64
    model.add(Dense(64, kernel_regularizer=REGULARIZER, activation='relu'))
    #add output layer with a single neuron and a sigmoind activation to represent the binary classification
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def train_model(X_train, y_train, X_valid, y_valid):
    
    #callbacks = [EarlyStopping(patience=10, restore_best_weights=True)]
    model = create_model(INPUT_SHAPE)
    model.compile(optimizer=OPTIMIZER(),
              loss=LOSS_FUNCTION(),
              metrics=METRICS)
    model_history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_valid, y_valid), verbose=VERBOSE)
    clear_session()

    return (model, model_history)

# %%
folds = KFold(n_splits=5, shuffle=True, random_state=42)
folds.get_n_splits(training_images)
model_histories = []
validation_scores = []
for fold_index, (train_index, valid_index) in enumerate(folds.split(training_images)):
    X_train, X_valid = training_images[train_index], training_images[valid_index]
    y_train, y_valid = training_labels[train_index], training_labels[valid_index]
    print('Training model for fold:', fold_index + 1)
    model, model_history = train_model(X_train, y_train, X_valid, y_valid)
    model_histories.append(model_history)
    validation_score = model.evaluate(X_valid, y_valid)
    validation_scores.append(validation_score)

[print('validation_score for fold number ', str(index+1), ':' , str(validation_score)) for index, validation_score in enumerate(validation_scores)]
# Out:
# Training model for fold: 1
# Epoch 1/50
# 100/100 - 149s - 1s/step - accuracy: 0.5024 - loss: 0.8935 - val_accuracy: 0.5101 - val_loss: 0.6973
# Epoch 2/50
# 100/100 - 149s - 1s/step - accuracy: 0.5300 - loss: 0.6990 - val_accuracy: 0.5138 - val_loss: 0.7123
# Epoch 3/50
# 100/100 - 145s - 1s/step - accuracy: 0.5181 - loss: 0.7053 - val_accuracy: 0.5490 - val_loss: 0.7000
# Epoch 4/50
# 100/100 - 146s - 1s/step - accuracy: 0.5350 - loss: 0.7124 - val_accuracy: 0.5088 - val_loss: 0.7462
# Epoch 5/50
# 100/100 - 141s - 1s/step - accuracy: 0.5306 - loss: 0.7349 - val_accuracy: 0.5038 - val_loss: 0.7284
# Epoch 6/50
# 100/100 - 140s - 1s/step - accuracy: 0.5454 - loss: 0.7209 - val_accuracy: 0.5477 - val_loss: 0.7052
# Epoch 7/50
# 100/100 - 144s - 1s/step - accuracy: 0.5595 - loss: 0.7206 - val_accuracy: 0.5314 - val_loss: 0.7227
# Epoch 8/50
# 100/100 - 147s - 1s/step - accuracy: 0.5768 - loss: 0.7178 - val_accuracy: 0.5515 - val_loss: 0.7335
# Epoch 9/50
# 100/100 - 146s - 1s/step - accuracy: 0.5866 - loss: 0.7224 - val_accuracy: 0.5503 - val_loss: 0.7370
# Epoch 10/50
# 100/100 - 151s - 2s/step - accuracy: 0.6038 - loss: 0.7124 - val_accuracy: 0.5025 - val_loss: 0.7743
# Epoch 11/50
# 100/100 - 140s - 1s/step - accuracy: 0.6155 - loss: 0.7020 - val_accuracy: 0.5553 - val_loss: 0.7610
# Epoch 12/50
# 100/100 - 141s - 1s/step - accuracy: 0.6516 - loss: 0.6942 - val_accuracy: 0.5616 - val_loss: 0.7715
# Epoch 13/50
# 100/100 - 142s - 1s/step - accuracy: 0.6629 - loss: 0.6833 - val_accuracy: 0.5440 - val_loss: 0.7954
# Epoch 14/50
# 100/100 - 142s - 1s/step - accuracy: 0.6971 - loss: 0.6675 - val_accuracy: 0.5503 - val_loss: 0.8461
# Epoch 15/50
# 100/100 - 147s - 1s/step - accuracy: 0.7166 - loss: 0.6520 - val_accuracy: 0.5452 - val_loss: 0.8423
# Epoch 16/50
# 100/100 - 145s - 1s/step - accuracy: 0.7462 - loss: 0.6279 - val_accuracy: 0.5402 - val_loss: 0.9177
# Epoch 17/50
# 100/100 - 146s - 1s/step - accuracy: 0.7725 - loss: 0.6185 - val_accuracy: 0.5515 - val_loss: 0.9887
# Epoch 18/50
# 100/100 - 146s - 1s/step - accuracy: 0.7883 - loss: 0.6079 - val_accuracy: 0.5641 - val_loss: 0.9933
# Epoch 19/50
# 100/100 - 146s - 1s/step - accuracy: 0.8275 - loss: 0.5737 - val_accuracy: 0.5754 - val_loss: 1.0494
# Epoch 20/50
# 100/100 - 146s - 1s/step - accuracy: 0.8420 - loss: 0.5547 - val_accuracy: 0.5603 - val_loss: 1.1259
# Epoch 21/50
# 100/100 - 146s - 1s/step - accuracy: 0.8615 - loss: 0.5597 - val_accuracy: 0.5892 - val_loss: 1.2242
# Epoch 22/50
# 100/100 - 147s - 1s/step - accuracy: 0.8555 - loss: 0.6032 - val_accuracy: 0.5829 - val_loss: 1.2277
# Epoch 23/50
# 100/100 - 144s - 1s/step - accuracy: 0.9007 - loss: 0.4895 - val_accuracy: 0.5967 - val_loss: 1.3339
# Epoch 24/50
# 100/100 - 142s - 1s/step - accuracy: 0.9233 - loss: 0.4234 - val_accuracy: 0.5980 - val_loss: 1.3733
# Epoch 25/50
# 100/100 - 141s - 1s/step - accuracy: 0.9196 - loss: 0.4335 - val_accuracy: 0.5917 - val_loss: 1.5037
# Epoch 26/50
# 100/100 - 142s - 1s/step - accuracy: 0.9171 - loss: 0.4173 - val_accuracy: 0.5741 - val_loss: 1.3691
# Epoch 27/50
# 100/100 - 141s - 1s/step - accuracy: 0.9218 - loss: 0.4304 - val_accuracy: 0.5992 - val_loss: 1.4609
# Epoch 28/50
# 100/100 - 143s - 1s/step - accuracy: 0.9422 - loss: 0.3764 - val_accuracy: 0.5842 - val_loss: 1.5711
# Epoch 29/50
# 100/100 - 140s - 1s/step - accuracy: 0.9375 - loss: 0.3775 - val_accuracy: 0.5967 - val_loss: 1.6790
# Epoch 30/50
# 100/100 - 139s - 1s/step - accuracy: 0.9375 - loss: 0.4039 - val_accuracy: 0.5879 - val_loss: 1.7756
# Epoch 31/50
# 100/100 - 140s - 1s/step - accuracy: 0.9425 - loss: 0.3982 - val_accuracy: 0.5892 - val_loss: 1.5934
# Epoch 32/50
# 100/100 - 139s - 1s/step - accuracy: 0.9397 - loss: 0.4079 - val_accuracy: 0.5741 - val_loss: 1.7558
# Epoch 33/50
# 100/100 - 140s - 1s/step - accuracy: 0.9438 - loss: 0.4038 - val_accuracy: 0.5892 - val_loss: 1.7579
# Epoch 34/50
# 100/100 - 139s - 1s/step - accuracy: 0.9456 - loss: 0.3958 - val_accuracy: 0.5992 - val_loss: 1.8089
# Epoch 35/50
# 100/100 - 141s - 1s/step - accuracy: 0.9563 - loss: 0.3597 - val_accuracy: 0.5905 - val_loss: 1.9045
# Epoch 36/50
# 100/100 - 140s - 1s/step - accuracy: 0.9651 - loss: 0.3234 - val_accuracy: 0.5829 - val_loss: 2.0180
# Epoch 37/50
# 100/100 - 139s - 1s/step - accuracy: 0.9592 - loss: 0.3319 - val_accuracy: 0.5804 - val_loss: 2.1794
# Epoch 38/50
# 100/100 - 139s - 1s/step - accuracy: 0.9566 - loss: 0.3282 - val_accuracy: 0.6106 - val_loss: 2.0585
# Epoch 39/50
# 100/100 - 139s - 1s/step - accuracy: 0.9604 - loss: 0.3200 - val_accuracy: 0.5867 - val_loss: 2.0486
# Epoch 40/50
# 100/100 - 139s - 1s/step - accuracy: 0.9544 - loss: 0.3670 - val_accuracy: 0.5628 - val_loss: 2.2218
# Epoch 41/50
# 100/100 - 139s - 1s/step - accuracy: 0.9387 - loss: 0.4031 - val_accuracy: 0.5779 - val_loss: 2.0437
# Epoch 42/50
# 100/100 - 139s - 1s/step - accuracy: 0.9680 - loss: 0.3212 - val_accuracy: 0.5716 - val_loss: 2.2138
# Epoch 43/50
# 100/100 - 139s - 1s/step - accuracy: 0.9717 - loss: 0.3063 - val_accuracy: 0.5829 - val_loss: 2.4930
# Epoch 44/50
# 100/100 - 140s - 1s/step - accuracy: 0.9724 - loss: 0.2936 - val_accuracy: 0.5917 - val_loss: 2.3029
# Epoch 45/50
# 100/100 - 139s - 1s/step - accuracy: 0.9739 - loss: 0.2905 - val_accuracy: 0.5791 - val_loss: 2.1285
# Epoch 46/50
# 100/100 - 143s - 1s/step - accuracy: 0.9579 - loss: 0.3259 - val_accuracy: 0.6068 - val_loss: 2.0835
# Epoch 47/50
# 100/100 - 137s - 1s/step - accuracy: 0.9485 - loss: 0.3678 - val_accuracy: 0.5666 - val_loss: 2.1236
# Epoch 48/50
# 100/100 - 143s - 1s/step - accuracy: 0.9526 - loss: 0.3816 - val_accuracy: 0.5879 - val_loss: 2.1628
# Epoch 49/50
# 100/100 - 141s - 1s/step - accuracy: 0.9610 - loss: 0.3401 - val_accuracy: 0.6005 - val_loss: 2.1018
# Epoch 50/50
# 100/100 - 134s - 1s/step - accuracy: 0.9727 - loss: 0.3248 - val_accuracy: 0.5829 - val_loss: 2.2759
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 364ms/step - accuracy: 0.6166 - loss: 2.1549
# Training model for fold: 2
# Epoch 1/50
# 100/100 - 136s - 1s/step - accuracy: 0.5104 - loss: 0.9465 - val_accuracy: 0.5013 - val_loss: 0.6959
# Epoch 2/50
# 100/100 - 143s - 1s/step - accuracy: 0.4967 - loss: 0.6952 - val_accuracy: 0.5540 - val_loss: 0.6930
# Epoch 3/50
# 100/100 - 142s - 1s/step - accuracy: 0.5118 - loss: 0.6949 - val_accuracy: 0.5226 - val_loss: 0.6927
# Epoch 4/50
# 100/100 - 151s - 2s/step - accuracy: 0.5441 - loss: 0.6974 - val_accuracy: 0.5452 - val_loss: 0.7030
# Epoch 5/50
# 100/100 - 140s - 1s/step - accuracy: 0.5225 - loss: 0.6968 - val_accuracy: 0.5465 - val_loss: 0.6942
# Epoch 6/50
# 100/100 - 140s - 1s/step - accuracy: 0.5303 - loss: 0.7013 - val_accuracy: 0.5515 - val_loss: 0.6959
# Epoch 7/50
# 100/100 - 142s - 1s/step - accuracy: 0.5300 - loss: 0.7066 - val_accuracy: 0.5276 - val_loss: 0.7089
# Epoch 8/50
# 100/100 - 140s - 1s/step - accuracy: 0.5476 - loss: 0.7073 - val_accuracy: 0.5590 - val_loss: 0.7066
# Epoch 9/50
# 100/100 - 141s - 1s/step - accuracy: 0.5520 - loss: 0.7088 - val_accuracy: 0.5565 - val_loss: 0.7073
# Epoch 10/50
# 100/100 - 147s - 1s/step - accuracy: 0.5624 - loss: 0.7089 - val_accuracy: 0.5666 - val_loss: 0.7006
# Epoch 11/50
# 100/100 - 142s - 1s/step - accuracy: 0.5837 - loss: 0.7030 - val_accuracy: 0.5603 - val_loss: 0.7264
# Epoch 12/50
# 100/100 - 142s - 1s/step - accuracy: 0.5966 - loss: 0.7070 - val_accuracy: 0.5377 - val_loss: 0.7215
# Epoch 13/50
# 100/100 - 141s - 1s/step - accuracy: 0.6120 - loss: 0.6977 - val_accuracy: 0.5628 - val_loss: 0.7244
# Epoch 14/50
# 100/100 - 142s - 1s/step - accuracy: 0.6331 - loss: 0.6910 - val_accuracy: 0.5603 - val_loss: 0.7303
# Epoch 15/50
# 100/100 - 140s - 1s/step - accuracy: 0.6434 - loss: 0.6892 - val_accuracy: 0.5741 - val_loss: 0.7318
# Epoch 16/50
# 100/100 - 139s - 1s/step - accuracy: 0.6682 - loss: 0.6664 - val_accuracy: 0.5377 - val_loss: 0.7973
# Epoch 17/50
# 100/100 - 139s - 1s/step - accuracy: 0.6843 - loss: 0.6670 - val_accuracy: 0.5590 - val_loss: 0.7801
# Epoch 18/50
# 100/100 - 139s - 1s/step - accuracy: 0.6931 - loss: 0.6565 - val_accuracy: 0.5603 - val_loss: 0.7912
# Epoch 19/50
# 100/100 - 139s - 1s/step - accuracy: 0.7116 - loss: 0.6528 - val_accuracy: 0.5716 - val_loss: 0.8027
# Epoch 20/50
# 100/100 - 139s - 1s/step - accuracy: 0.7355 - loss: 0.6415 - val_accuracy: 0.5666 - val_loss: 0.8665
# Epoch 21/50
# 100/100 - 139s - 1s/step - accuracy: 0.7622 - loss: 0.6388 - val_accuracy: 0.5553 - val_loss: 0.9259
# Epoch 22/50
# 100/100 - 140s - 1s/step - accuracy: 0.7568 - loss: 0.6715 - val_accuracy: 0.5528 - val_loss: 1.0867
# Epoch 23/50
# 100/100 - 139s - 1s/step - accuracy: 0.7901 - loss: 0.6658 - val_accuracy: 0.5754 - val_loss: 1.0837
# Epoch 24/50
# 100/100 - 140s - 1s/step - accuracy: 0.8021 - loss: 0.6542 - val_accuracy: 0.5540 - val_loss: 1.0811
# Epoch 25/50
# 100/100 - 139s - 1s/step - accuracy: 0.8332 - loss: 0.5814 - val_accuracy: 0.5691 - val_loss: 1.1722
# Epoch 26/50
# 100/100 - 140s - 1s/step - accuracy: 0.8432 - loss: 0.5866 - val_accuracy: 0.5854 - val_loss: 1.2052
# Epoch 27/50
# 100/100 - 143s - 1s/step - accuracy: 0.8640 - loss: 0.5638 - val_accuracy: 0.5817 - val_loss: 1.2913
# Epoch 28/50
# 100/100 - 140s - 1s/step - accuracy: 0.8567 - loss: 0.5734 - val_accuracy: 0.5791 - val_loss: 1.3887
# Epoch 29/50
# 100/100 - 139s - 1s/step - accuracy: 0.8765 - loss: 0.5277 - val_accuracy: 0.5967 - val_loss: 1.2910
# Epoch 30/50
# 100/100 - 139s - 1s/step - accuracy: 0.8948 - loss: 0.4593 - val_accuracy: 0.5892 - val_loss: 1.2534
# Epoch 31/50
# 100/100 - 139s - 1s/step - accuracy: 0.9001 - loss: 0.4506 - val_accuracy: 0.5779 - val_loss: 1.4597
# Epoch 32/50
# 100/100 - 139s - 1s/step - accuracy: 0.9054 - loss: 0.4512 - val_accuracy: 0.5791 - val_loss: 1.4952
# Epoch 33/50
# 100/100 - 139s - 1s/step - accuracy: 0.9230 - loss: 0.4155 - val_accuracy: 0.6269 - val_loss: 1.4555
# Epoch 34/50
# 100/100 - 139s - 1s/step - accuracy: 0.9127 - loss: 0.4403 - val_accuracy: 0.5992 - val_loss: 1.4689
# Epoch 35/50
# 100/100 - 139s - 1s/step - accuracy: 0.9227 - loss: 0.4373 - val_accuracy: 0.5942 - val_loss: 1.6110
# Epoch 36/50
# 100/100 - 139s - 1s/step - accuracy: 0.9136 - loss: 0.4573 - val_accuracy: 0.5905 - val_loss: 1.7085
# Epoch 37/50
# 100/100 - 140s - 1s/step - accuracy: 0.9340 - loss: 0.3782 - val_accuracy: 0.5967 - val_loss: 1.7417
# Epoch 38/50
# 100/100 - 143s - 1s/step - accuracy: 0.9554 - loss: 0.3398 - val_accuracy: 0.5967 - val_loss: 1.7364
# Epoch 39/50
# 100/100 - 140s - 1s/step - accuracy: 0.9463 - loss: 0.3418 - val_accuracy: 0.6005 - val_loss: 1.7692
# Epoch 40/50
# 100/100 - 143s - 1s/step - accuracy: 0.9406 - loss: 0.3818 - val_accuracy: 0.5917 - val_loss: 1.8497
# Epoch 41/50
# 100/100 - 139s - 1s/step - accuracy: 0.9406 - loss: 0.3592 - val_accuracy: 0.5917 - val_loss: 1.8430
# Epoch 42/50
# 100/100 - 138s - 1s/step - accuracy: 0.9306 - loss: 0.4089 - val_accuracy: 0.5867 - val_loss: 1.8365
# Epoch 43/50
# 100/100 - 139s - 1s/step - accuracy: 0.9356 - loss: 0.4141 - val_accuracy: 0.6118 - val_loss: 1.8300
# Epoch 44/50
# 100/100 - 138s - 1s/step - accuracy: 0.9588 - loss: 0.3257 - val_accuracy: 0.6118 - val_loss: 1.9918
# Epoch 45/50
# 100/100 - 140s - 1s/step - accuracy: 0.9557 - loss: 0.3434 - val_accuracy: 0.6181 - val_loss: 1.8794
# Epoch 46/50
# 100/100 - 139s - 1s/step - accuracy: 0.9488 - loss: 0.3479 - val_accuracy: 0.5992 - val_loss: 2.0407
# Epoch 47/50
# 100/100 - 140s - 1s/step - accuracy: 0.9456 - loss: 0.3638 - val_accuracy: 0.6093 - val_loss: 2.0477
# Epoch 48/50
# 100/100 - 141s - 1s/step - accuracy: 0.9447 - loss: 0.3721 - val_accuracy: 0.5992 - val_loss: 2.0182
# Epoch 49/50
# 100/100 - 140s - 1s/step - accuracy: 0.9463 - loss: 0.3890 - val_accuracy: 0.5754 - val_loss: 2.0022
# Epoch 50/50
# 100/100 - 140s - 1s/step - accuracy: 0.9614 - loss: 0.3214 - val_accuracy: 0.6055 - val_loss: 2.1718
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 362ms/step - accuracy: 0.5944 - loss: 2.4200
# Training model for fold: 3
# Epoch 1/50
# 100/100 - 146s - 1s/step - accuracy: 0.5343 - loss: 0.8654 - val_accuracy: 0.5415 - val_loss: 0.6963
# Epoch 2/50
# 100/100 - 146s - 1s/step - accuracy: 0.5143 - loss: 0.7018 - val_accuracy: 0.5226 - val_loss: 0.7092
# Epoch 3/50
# 100/100 - 144s - 1s/step - accuracy: 0.5322 - loss: 0.7098 - val_accuracy: 0.5276 - val_loss: 0.7130
# Epoch 4/50
# 100/100 - 139s - 1s/step - accuracy: 0.5570 - loss: 0.7156 - val_accuracy: 0.5013 - val_loss: 0.7098
# Epoch 5/50
# 100/100 - 139s - 1s/step - accuracy: 0.5489 - loss: 0.7109 - val_accuracy: 0.5088 - val_loss: 0.7294
# Epoch 6/50
# 100/100 - 139s - 1s/step - accuracy: 0.5608 - loss: 0.7086 - val_accuracy: 0.5427 - val_loss: 0.7201
# Epoch 7/50
# 100/100 - 140s - 1s/step - accuracy: 0.5743 - loss: 0.7082 - val_accuracy: 0.5339 - val_loss: 0.7185
# Epoch 8/50
# 100/100 - 140s - 1s/step - accuracy: 0.5891 - loss: 0.7053 - val_accuracy: 0.5389 - val_loss: 0.7221
# Epoch 9/50
# 100/100 - 143s - 1s/step - accuracy: 0.6089 - loss: 0.7052 - val_accuracy: 0.5352 - val_loss: 0.7366
# Epoch 10/50
# 100/100 - 142s - 1s/step - accuracy: 0.6271 - loss: 0.6941 - val_accuracy: 0.5540 - val_loss: 0.7503
# Epoch 11/50
# 100/100 - 139s - 1s/step - accuracy: 0.6585 - loss: 0.6862 - val_accuracy: 0.5653 - val_loss: 0.7705
# Epoch 12/50
# 100/100 - 139s - 1s/step - accuracy: 0.6711 - loss: 0.6709 - val_accuracy: 0.5553 - val_loss: 0.7887
# Epoch 13/50
# 100/100 - 139s - 1s/step - accuracy: 0.7144 - loss: 0.6451 - val_accuracy: 0.5653 - val_loss: 0.8273
# Epoch 14/50
# 100/100 - 139s - 1s/step - accuracy: 0.7298 - loss: 0.6300 - val_accuracy: 0.5879 - val_loss: 0.8739
# Epoch 15/50
# 100/100 - 139s - 1s/step - accuracy: 0.7590 - loss: 0.6148 - val_accuracy: 0.6080 - val_loss: 0.9171
# Epoch 16/50
# 100/100 - 139s - 1s/step - accuracy: 0.7763 - loss: 0.6382 - val_accuracy: 0.5892 - val_loss: 0.9605
# Epoch 17/50
# 100/100 - 139s - 1s/step - accuracy: 0.8018 - loss: 0.5971 - val_accuracy: 0.5917 - val_loss: 1.0657
# Epoch 18/50
# 100/100 - 152s - 2s/step - accuracy: 0.8253 - loss: 0.5756 - val_accuracy: 0.5980 - val_loss: 1.1213
# Epoch 19/50
# 100/100 - 156s - 2s/step - accuracy: 0.8347 - loss: 0.5488 - val_accuracy: 0.6018 - val_loss: 1.1498
# Epoch 20/50
# 100/100 - 156s - 2s/step - accuracy: 0.8658 - loss: 0.4768 - val_accuracy: 0.6043 - val_loss: 1.2286
# Epoch 21/50
# 100/100 - 156s - 2s/step - accuracy: 0.8611 - loss: 0.5012 - val_accuracy: 0.6143 - val_loss: 1.3026
# Epoch 22/50
# 100/100 - 156s - 2s/step - accuracy: 0.8797 - loss: 0.4879 - val_accuracy: 0.6231 - val_loss: 1.3738
# Epoch 23/50
# 100/100 - 157s - 2s/step - accuracy: 0.8966 - loss: 0.4661 - val_accuracy: 0.6156 - val_loss: 1.2646
# Epoch 24/50
# 100/100 - 157s - 2s/step - accuracy: 0.9045 - loss: 0.4326 - val_accuracy: 0.6244 - val_loss: 1.4820
# Epoch 25/50
# 100/100 - 156s - 2s/step - accuracy: 0.9145 - loss: 0.4228 - val_accuracy: 0.6118 - val_loss: 1.5076
# Epoch 26/50
# 100/100 - 157s - 2s/step - accuracy: 0.9262 - loss: 0.3977 - val_accuracy: 0.6231 - val_loss: 1.4861
# Epoch 27/50
# 100/100 - 156s - 2s/step - accuracy: 0.9249 - loss: 0.4151 - val_accuracy: 0.6156 - val_loss: 1.7036
# Epoch 28/50
# 100/100 - 157s - 2s/step - accuracy: 0.9240 - loss: 0.4081 - val_accuracy: 0.6307 - val_loss: 1.7780
# Epoch 29/50
# 100/100 - 156s - 2s/step - accuracy: 0.9384 - loss: 0.3758 - val_accuracy: 0.6168 - val_loss: 1.5678
# Epoch 30/50
# 100/100 - 155s - 2s/step - accuracy: 0.9472 - loss: 0.3351 - val_accuracy: 0.6118 - val_loss: 1.7305
# Epoch 31/50
# 100/100 - 153s - 2s/step - accuracy: 0.9485 - loss: 0.3323 - val_accuracy: 0.6168 - val_loss: 1.7587
# Epoch 32/50
# 100/100 - 153s - 2s/step - accuracy: 0.9337 - loss: 0.3536 - val_accuracy: 0.6093 - val_loss: 1.7621
# Epoch 33/50
# 100/100 - 153s - 2s/step - accuracy: 0.9362 - loss: 0.3654 - val_accuracy: 0.6206 - val_loss: 1.8241
# Epoch 34/50
# 100/100 - 153s - 2s/step - accuracy: 0.9221 - loss: 0.4117 - val_accuracy: 0.6131 - val_loss: 1.4865
# Epoch 35/50
# 100/100 - 153s - 2s/step - accuracy: 0.9233 - loss: 0.4246 - val_accuracy: 0.6080 - val_loss: 1.9347
# Epoch 36/50
# 100/100 - 153s - 2s/step - accuracy: 0.9601 - loss: 0.3459 - val_accuracy: 0.6357 - val_loss: 1.9330
# Epoch 37/50
# 100/100 - 153s - 2s/step - accuracy: 0.9617 - loss: 0.3055 - val_accuracy: 0.6080 - val_loss: 1.9144
# Epoch 38/50
# 100/100 - 153s - 2s/step - accuracy: 0.9570 - loss: 0.3048 - val_accuracy: 0.6118 - val_loss: 2.1295
# Epoch 39/50
# 100/100 - 153s - 2s/step - accuracy: 0.9500 - loss: 0.3343 - val_accuracy: 0.6332 - val_loss: 1.9868
# Epoch 40/50
# 100/100 - 153s - 2s/step - accuracy: 0.9519 - loss: 0.3467 - val_accuracy: 0.6181 - val_loss: 1.8875
# Epoch 41/50
# 100/100 - 144s - 1s/step - accuracy: 0.9626 - loss: 0.3065 - val_accuracy: 0.6181 - val_loss: 2.1432
# Epoch 42/50
# 100/100 - 135s - 1s/step - accuracy: 0.9447 - loss: 0.3543 - val_accuracy: 0.6018 - val_loss: 2.2967
# Epoch 43/50
# 100/100 - 135s - 1s/step - accuracy: 0.9475 - loss: 0.3563 - val_accuracy: 0.5967 - val_loss: 2.0434
# Epoch 44/50
# 100/100 - 136s - 1s/step - accuracy: 0.9576 - loss: 0.3267 - val_accuracy: 0.6193 - val_loss: 1.9387
# Epoch 45/50
# 100/100 - 135s - 1s/step - accuracy: 0.9683 - loss: 0.3015 - val_accuracy: 0.6005 - val_loss: 2.2221
# Epoch 46/50
# 100/100 - 135s - 1s/step - accuracy: 0.9705 - loss: 0.2784 - val_accuracy: 0.5967 - val_loss: 2.0176
# Epoch 47/50
# 100/100 - 135s - 1s/step - accuracy: 0.9802 - loss: 0.2469 - val_accuracy: 0.6068 - val_loss: 2.1513
# Epoch 48/50
# 100/100 - 139s - 1s/step - accuracy: 0.9538 - loss: 0.3362 - val_accuracy: 0.6093 - val_loss: 1.9823
# Epoch 49/50
# 100/100 - 135s - 1s/step - accuracy: 0.9400 - loss: 0.3885 - val_accuracy: 0.6043 - val_loss: 2.0430
# Epoch 50/50
# 100/100 - 135s - 1s/step - accuracy: 0.9724 - loss: 0.2954 - val_accuracy: 0.6319 - val_loss: 2.0292
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 355ms/step - accuracy: 0.6198 - loss: 1.9219
# Training model for fold: 4
# Epoch 1/50
# 100/100 - 136s - 1s/step - accuracy: 0.5220 - loss: 0.9913 - val_accuracy: 0.5063 - val_loss: 0.6973
# Epoch 2/50
# 100/100 - 135s - 1s/step - accuracy: 0.5168 - loss: 0.6959 - val_accuracy: 0.5151 - val_loss: 0.6949
# Epoch 3/50
# 100/100 - 135s - 1s/step - accuracy: 0.5212 - loss: 0.6981 - val_accuracy: 0.5590 - val_loss: 0.6971
# Epoch 4/50
# 100/100 - 135s - 1s/step - accuracy: 0.5473 - loss: 0.7019 - val_accuracy: 0.5402 - val_loss: 0.7002
# Epoch 5/50
# 100/100 - 135s - 1s/step - accuracy: 0.5291 - loss: 0.7162 - val_accuracy: 0.5151 - val_loss: 0.7029
# Epoch 6/50
# 100/100 - 135s - 1s/step - accuracy: 0.5316 - loss: 0.7048 - val_accuracy: 0.5515 - val_loss: 0.6993
# Epoch 7/50
# 100/100 - 135s - 1s/step - accuracy: 0.5401 - loss: 0.7192 - val_accuracy: 0.5063 - val_loss: 0.7115
# Epoch 8/50
# 100/100 - 135s - 1s/step - accuracy: 0.5429 - loss: 0.7172 - val_accuracy: 0.5163 - val_loss: 0.7198
# Epoch 9/50
# 100/100 - 135s - 1s/step - accuracy: 0.5489 - loss: 0.7134 - val_accuracy: 0.5477 - val_loss: 0.6996
# Epoch 10/50
# 100/100 - 136s - 1s/step - accuracy: 0.5696 - loss: 0.7089 - val_accuracy: 0.5540 - val_loss: 0.7109
# Epoch 11/50
# 100/100 - 134s - 1s/step - accuracy: 0.5752 - loss: 0.7039 - val_accuracy: 0.5691 - val_loss: 0.7113
# Epoch 12/50
# 100/100 - 134s - 1s/step - accuracy: 0.5825 - loss: 0.7063 - val_accuracy: 0.5264 - val_loss: 0.7229
# Epoch 13/50
# 100/100 - 135s - 1s/step - accuracy: 0.5881 - loss: 0.7143 - val_accuracy: 0.5415 - val_loss: 0.7300
# Epoch 14/50
# 100/100 - 134s - 1s/step - accuracy: 0.6211 - loss: 0.6966 - val_accuracy: 0.5766 - val_loss: 0.7286
# Epoch 15/50
# 100/100 - 134s - 1s/step - accuracy: 0.6488 - loss: 0.6923 - val_accuracy: 0.5616 - val_loss: 0.7666
# Epoch 16/50
# 100/100 - 135s - 1s/step - accuracy: 0.6642 - loss: 0.6860 - val_accuracy: 0.5879 - val_loss: 0.7965
# Epoch 17/50
# 100/100 - 134s - 1s/step - accuracy: 0.6902 - loss: 0.6730 - val_accuracy: 0.5804 - val_loss: 0.8197
# Epoch 18/50
# 100/100 - 135s - 1s/step - accuracy: 0.7113 - loss: 0.6605 - val_accuracy: 0.5867 - val_loss: 0.8472
# Epoch 19/50
# 100/100 - 135s - 1s/step - accuracy: 0.7446 - loss: 0.6403 - val_accuracy: 0.6030 - val_loss: 0.8750
# Epoch 20/50
# 100/100 - 135s - 1s/step - accuracy: 0.7672 - loss: 0.5952 - val_accuracy: 0.5804 - val_loss: 0.9287
# Epoch 21/50
# 100/100 - 134s - 1s/step - accuracy: 0.7741 - loss: 0.6180 - val_accuracy: 0.5741 - val_loss: 1.0924
# Epoch 22/50
# 100/100 - 134s - 1s/step - accuracy: 0.8046 - loss: 0.6113 - val_accuracy: 0.5829 - val_loss: 1.0455
# Epoch 23/50
# 100/100 - 134s - 1s/step - accuracy: 0.8253 - loss: 0.5707 - val_accuracy: 0.5503 - val_loss: 1.2272
# Epoch 24/50
# 100/100 - 135s - 1s/step - accuracy: 0.8426 - loss: 0.5742 - val_accuracy: 0.5779 - val_loss: 1.1821
# Epoch 25/50
# 100/100 - 135s - 1s/step - accuracy: 0.8527 - loss: 0.5615 - val_accuracy: 0.5930 - val_loss: 1.2751
# Epoch 26/50
# 100/100 - 135s - 1s/step - accuracy: 0.8740 - loss: 0.5163 - val_accuracy: 0.5804 - val_loss: 1.3080
# Epoch 27/50
# 100/100 - 135s - 1s/step - accuracy: 0.8979 - loss: 0.4353 - val_accuracy: 0.5892 - val_loss: 1.3731
# Epoch 28/50
# 100/100 - 134s - 1s/step - accuracy: 0.9045 - loss: 0.4470 - val_accuracy: 0.5741 - val_loss: 1.6526
# Epoch 29/50
# 100/100 - 134s - 1s/step - accuracy: 0.8966 - loss: 0.4816 - val_accuracy: 0.5879 - val_loss: 1.5176
# Epoch 30/50
# 100/100 - 134s - 1s/step - accuracy: 0.8966 - loss: 0.4612 - val_accuracy: 0.5829 - val_loss: 1.3554
# Epoch 31/50
# 100/100 - 134s - 1s/step - accuracy: 0.9142 - loss: 0.4193 - val_accuracy: 0.5817 - val_loss: 1.5808
# Epoch 32/50
# 100/100 - 134s - 1s/step - accuracy: 0.9315 - loss: 0.3828 - val_accuracy: 0.6030 - val_loss: 1.5921
# Epoch 33/50
# 100/100 - 135s - 1s/step - accuracy: 0.9375 - loss: 0.3799 - val_accuracy: 0.6106 - val_loss: 1.7364
# Epoch 34/50
# 100/100 - 135s - 1s/step - accuracy: 0.9406 - loss: 0.3660 - val_accuracy: 0.5980 - val_loss: 1.7674
# Epoch 35/50
# 100/100 - 134s - 1s/step - accuracy: 0.9365 - loss: 0.3792 - val_accuracy: 0.5515 - val_loss: 1.8484
# Epoch 36/50
# 100/100 - 135s - 1s/step - accuracy: 0.9403 - loss: 0.3821 - val_accuracy: 0.5691 - val_loss: 1.9522
# Epoch 37/50
# 100/100 - 135s - 1s/step - accuracy: 0.9164 - loss: 0.4493 - val_accuracy: 0.5678 - val_loss: 1.7697
# Epoch 38/50
# 100/100 - 136s - 1s/step - accuracy: 0.9343 - loss: 0.3992 - val_accuracy: 0.5892 - val_loss: 1.9208
# Epoch 39/50
# 100/100 - 135s - 1s/step - accuracy: 0.9456 - loss: 0.3734 - val_accuracy: 0.5992 - val_loss: 1.9765
# Epoch 40/50
# 100/100 - 135s - 1s/step - accuracy: 0.9535 - loss: 0.3309 - val_accuracy: 0.6005 - val_loss: 1.9426
# Epoch 41/50
# 100/100 - 134s - 1s/step - accuracy: 0.9563 - loss: 0.3248 - val_accuracy: 0.5905 - val_loss: 2.0218
# Epoch 42/50
# 100/100 - 134s - 1s/step - accuracy: 0.9554 - loss: 0.3367 - val_accuracy: 0.5867 - val_loss: 2.2023
# Epoch 43/50
# 100/100 - 135s - 1s/step - accuracy: 0.9403 - loss: 0.3750 - val_accuracy: 0.6244 - val_loss: 1.9577
# Epoch 44/50
# 100/100 - 134s - 1s/step - accuracy: 0.9557 - loss: 0.3331 - val_accuracy: 0.6030 - val_loss: 2.1076
# Epoch 45/50
# 100/100 - 135s - 1s/step - accuracy: 0.9387 - loss: 0.3938 - val_accuracy: 0.5867 - val_loss: 1.8897
# Epoch 46/50
# 100/100 - 134s - 1s/step - accuracy: 0.9551 - loss: 0.3402 - val_accuracy: 0.6080 - val_loss: 2.2620
# Epoch 47/50
# 100/100 - 134s - 1s/step - accuracy: 0.9664 - loss: 0.3019 - val_accuracy: 0.5980 - val_loss: 2.2693
# Epoch 48/50
# 100/100 - 134s - 1s/step - accuracy: 0.9702 - loss: 0.2879 - val_accuracy: 0.5829 - val_loss: 2.1347
# Epoch 49/50
# 100/100 - 134s - 1s/step - accuracy: 0.9573 - loss: 0.3161 - val_accuracy: 0.6005 - val_loss: 2.0787
# Epoch 50/50
# 100/100 - 135s - 1s/step - accuracy: 0.9497 - loss: 0.3379 - val_accuracy: 0.5892 - val_loss: 2.2794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 350ms/step - accuracy: 0.5736 - loss: 2.3183
# Training model for fold: 5
# Epoch 1/50
# 100/100 - 136s - 1s/step - accuracy: 0.5158 - loss: 0.9284 - val_accuracy: 0.5132 - val_loss: 0.7015
# Epoch 2/50
# 100/100 - 135s - 1s/step - accuracy: 0.5330 - loss: 0.7011 - val_accuracy: 0.5333 - val_loss: 0.7162
# Epoch 3/50
# 100/100 - 134s - 1s/step - accuracy: 0.5339 - loss: 0.7162 - val_accuracy: 0.5346 - val_loss: 0.7206
# Epoch 4/50
# 100/100 - 134s - 1s/step - accuracy: 0.5336 - loss: 0.7149 - val_accuracy: 0.5270 - val_loss: 0.7039
# Epoch 5/50
# 100/100 - 134s - 1s/step - accuracy: 0.5302 - loss: 0.7122 - val_accuracy: 0.5245 - val_loss: 0.7021
# Epoch 6/50
# 100/100 - 135s - 1s/step - accuracy: 0.5647 - loss: 0.7167 - val_accuracy: 0.5522 - val_loss: 0.7444
# Epoch 7/50
# 100/100 - 135s - 1s/step - accuracy: 0.5870 - loss: 0.7316 - val_accuracy: 0.5597 - val_loss: 0.7277
# Epoch 8/50
# 100/100 - 134s - 1s/step - accuracy: 0.5861 - loss: 0.7201 - val_accuracy: 0.5635 - val_loss: 0.7124
# Epoch 9/50
# 100/100 - 134s - 1s/step - accuracy: 0.6024 - loss: 0.7154 - val_accuracy: 0.5648 - val_loss: 0.7283
# Epoch 10/50
# 100/100 - 134s - 1s/step - accuracy: 0.6222 - loss: 0.7027 - val_accuracy: 0.5899 - val_loss: 0.7349
# Epoch 11/50
# 100/100 - 134s - 1s/step - accuracy: 0.6573 - loss: 0.6885 - val_accuracy: 0.5824 - val_loss: 0.7547
# Epoch 12/50
# 100/100 - 135s - 1s/step - accuracy: 0.6913 - loss: 0.6690 - val_accuracy: 0.6138 - val_loss: 0.7711
# Epoch 13/50
# 100/100 - 135s - 1s/step - accuracy: 0.7170 - loss: 0.6548 - val_accuracy: 0.6050 - val_loss: 0.8075
# Epoch 14/50
# 100/100 - 135s - 1s/step - accuracy: 0.7472 - loss: 0.6342 - val_accuracy: 0.6252 - val_loss: 0.8340
# Epoch 15/50
# 100/100 - 135s - 1s/step - accuracy: 0.7651 - loss: 0.6105 - val_accuracy: 0.6138 - val_loss: 0.8687
# Epoch 16/50
# 100/100 - 135s - 1s/step - accuracy: 0.8059 - loss: 0.5626 - val_accuracy: 0.6126 - val_loss: 0.9268
# Epoch 17/50
# 100/100 - 135s - 1s/step - accuracy: 0.8339 - loss: 0.5833 - val_accuracy: 0.6516 - val_loss: 1.0567
# Epoch 18/50
# 100/100 - 135s - 1s/step - accuracy: 0.8527 - loss: 0.5828 - val_accuracy: 0.6113 - val_loss: 1.1795
# Epoch 19/50
# 100/100 - 135s - 1s/step - accuracy: 0.8643 - loss: 0.5963 - val_accuracy: 0.6453 - val_loss: 1.2870
# Epoch 20/50
# 100/100 - 135s - 1s/step - accuracy: 0.8822 - loss: 0.5617 - val_accuracy: 0.6377 - val_loss: 1.2996
# Epoch 21/50
# 100/100 - 135s - 1s/step - accuracy: 0.8813 - loss: 0.5912 - val_accuracy: 0.6440 - val_loss: 1.3142
# Epoch 22/50
# 100/100 - 135s - 1s/step - accuracy: 0.9117 - loss: 0.4938 - val_accuracy: 0.6403 - val_loss: 1.2826
# Epoch 23/50
# 100/100 - 135s - 1s/step - accuracy: 0.9133 - loss: 0.4423 - val_accuracy: 0.6252 - val_loss: 1.4611
# Epoch 24/50
# 100/100 - 135s - 1s/step - accuracy: 0.9165 - loss: 0.4507 - val_accuracy: 0.6327 - val_loss: 1.6477
# Epoch 25/50
# 100/100 - 135s - 1s/step - accuracy: 0.9256 - loss: 0.4209 - val_accuracy: 0.6528 - val_loss: 1.4185
# Epoch 26/50
# 100/100 - 135s - 1s/step - accuracy: 0.9331 - loss: 0.4049 - val_accuracy: 0.6327 - val_loss: 1.5893
# Epoch 27/50
# 100/100 - 135s - 1s/step - accuracy: 0.9274 - loss: 0.4297 - val_accuracy: 0.6314 - val_loss: 1.6710
# Epoch 28/50
# 100/100 - 135s - 1s/step - accuracy: 0.9366 - loss: 0.3799 - val_accuracy: 0.6151 - val_loss: 1.5992
# Epoch 29/50
# 100/100 - 135s - 1s/step - accuracy: 0.9419 - loss: 0.3617 - val_accuracy: 0.6302 - val_loss: 1.7378
# Epoch 30/50
# 100/100 - 135s - 1s/step - accuracy: 0.9488 - loss: 0.3418 - val_accuracy: 0.6151 - val_loss: 1.8144
# Epoch 31/50
# 100/100 - 135s - 1s/step - accuracy: 0.9334 - loss: 0.3731 - val_accuracy: 0.6075 - val_loss: 1.9629
# Epoch 32/50
# 100/100 - 135s - 1s/step - accuracy: 0.9322 - loss: 0.3931 - val_accuracy: 0.6390 - val_loss: 1.8146
# Epoch 33/50
# 100/100 - 136s - 1s/step - accuracy: 0.9397 - loss: 0.3833 - val_accuracy: 0.6327 - val_loss: 1.8350
# Epoch 34/50
# 100/100 - 135s - 1s/step - accuracy: 0.9526 - loss: 0.3438 - val_accuracy: 0.6440 - val_loss: 1.7020
# Epoch 35/50
# 100/100 - 135s - 1s/step - accuracy: 0.9422 - loss: 0.3790 - val_accuracy: 0.6503 - val_loss: 1.7612
# Epoch 36/50
# 100/100 - 135s - 1s/step - accuracy: 0.9592 - loss: 0.3297 - val_accuracy: 0.6365 - val_loss: 1.9719
# Epoch 37/50
# 100/100 - 135s - 1s/step - accuracy: 0.9366 - loss: 0.3674 - val_accuracy: 0.6453 - val_loss: 1.8792
# Epoch 38/50
# 100/100 - 134s - 1s/step - accuracy: 0.9472 - loss: 0.3571 - val_accuracy: 0.6415 - val_loss: 2.0110
# Epoch 39/50
# 100/100 - 135s - 1s/step - accuracy: 0.9554 - loss: 0.3541 - val_accuracy: 0.6491 - val_loss: 1.9794
# Epoch 40/50
# 100/100 - 135s - 1s/step - accuracy: 0.9705 - loss: 0.2968 - val_accuracy: 0.6201 - val_loss: 2.0492
# Epoch 41/50
# 100/100 - 135s - 1s/step - accuracy: 0.9651 - loss: 0.2931 - val_accuracy: 0.6591 - val_loss: 2.1166
# Epoch 42/50
# 100/100 - 135s - 1s/step - accuracy: 0.9523 - loss: 0.3283 - val_accuracy: 0.6252 - val_loss: 1.9093
# Epoch 43/50
# 100/100 - 135s - 1s/step - accuracy: 0.9369 - loss: 0.3852 - val_accuracy: 0.6164 - val_loss: 2.0438
# Epoch 44/50
# 100/100 - 135s - 1s/step - accuracy: 0.9526 - loss: 0.3600 - val_accuracy: 0.6428 - val_loss: 2.0823
# Epoch 45/50
# 100/100 - 135s - 1s/step - accuracy: 0.9545 - loss: 0.3437 - val_accuracy: 0.6516 - val_loss: 1.9818
# Epoch 46/50
# 100/100 - 135s - 1s/step - accuracy: 0.9711 - loss: 0.3104 - val_accuracy: 0.6277 - val_loss: 2.2117
# Epoch 47/50
# 100/100 - 135s - 1s/step - accuracy: 0.9623 - loss: 0.3170 - val_accuracy: 0.6579 - val_loss: 2.0441
# Epoch 48/50
# 100/100 - 134s - 1s/step - accuracy: 0.9482 - loss: 0.3682 - val_accuracy: 0.6302 - val_loss: 1.9544
# Epoch 49/50
# 100/100 - 134s - 1s/step - accuracy: 0.9648 - loss: 0.3235 - val_accuracy: 0.6428 - val_loss: 2.0565
# Epoch 50/50
# 100/100 - 135s - 1s/step - accuracy: 0.9746 - loss: 0.2789 - val_accuracy: 0.6289 - val_loss: 2.3011
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 348ms/step - accuracy: 0.6091 - loss: 2.4103
# validation_score for fold number  1 : [2.275949478149414, 0.5829145908355713]
# validation_score for fold number  2 : [2.1717820167541504, 0.6055276393890381]
# validation_score for fold number  3 : [2.029205083847046, 0.6319095492362976]
# validation_score for fold number  4 : [2.279392957687378, 0.589195966720581]
# validation_score for fold number  5 : [2.301140069961548, 0.6289308071136475]
# [None, None, None, None, None]

# %%
model_histories[2].history
# Out:
# {'accuracy': [0.5343050956726074,
#   0.5142946839332581,
#   0.5322023034095764,
#   0.5570216774940491,
#   0.5488532781600952,
#   0.5607917308807373,
#   0.5743009448051453,
#   0.5890669226646423,
#   0.6088595390319824,
#   0.6270813941955566,
#   0.6584982872009277,
#   0.6710650324821472,
#   0.7144203782081604,
#   0.7298146486282349,
#   0.7590323686599731,
#   0.7763116359710693,
#   0.8017593622207642,
#   0.8253220319747925,
#   0.8347470760345459,
#   0.8658498525619507,
#   0.8611372709274292,
#   0.8796732425689697,
#   0.8966383934020996,
#   0.9044926166534424,
#   0.914546012878418,
#   0.926170289516449,
#   0.9249135851860046,
#   0.9239711165428162,
#   0.9384228587150574,
#   0.9472196102142334,
#   0.948476254940033,
#   0.9337103366851807,
#   0.9362236857414246,
#   0.9220860600471497,
#   0.923342764377594,
#   0.960100531578064,
#   0.9616713523864746,
#   0.9569588303565979,
#   0.9500471353530884,
#   0.9519321322441101,
#   0.9626138806343079,
#   0.9447062611579895,
#   0.9475337862968445,
#   0.9575871825218201,
#   0.9682689309120178,
#   0.9704681038856506,
#   0.9802073240280151,
#   0.9538171291351318,
#   0.9399937391281128,
#   0.9723531007766724],
#  'loss': [0.8653829097747803,
#   0.7018352746963501,
#   0.7097919583320618,
#   0.715595006942749,
#   0.7109176516532898,
#   0.7086261510848999,
#   0.7082358002662659,
#   0.7052909731864929,
#   0.7051647901535034,
#   0.6940842270851135,
#   0.6861586570739746,
#   0.6708746552467346,
#   0.6450634598731995,
#   0.6300275325775146,
#   0.6147855520248413,
#   0.638214647769928,
#   0.5971297025680542,
#   0.5756433606147766,
#   0.5488013029098511,
#   0.4767917990684509,
#   0.5012232065200806,
#   0.4879286289215088,
#   0.4660670757293701,
#   0.432576060295105,
#   0.42277660965919495,
#   0.39769527316093445,
#   0.4150891900062561,
#   0.40812408924102783,
#   0.37582170963287354,
#   0.3350837826728821,
#   0.3323470950126648,
#   0.3536476492881775,
#   0.3653968572616577,
#   0.411697655916214,
#   0.4246390461921692,
#   0.3459388017654419,
#   0.3054806590080261,
#   0.3047765791416168,
#   0.33429932594299316,
#   0.34670937061309814,
#   0.30653712153434753,
#   0.3543192148208618,
#   0.3562573492527008,
#   0.326704204082489,
#   0.30151185393333435,
#   0.2784422039985657,
#   0.2468908131122589,
#   0.33624526858329773,
#   0.3885231912136078,
#   0.29543590545654297],
#  'val_accuracy': [0.5414572954177856,
#   0.5226130485534668,
#   0.5276381969451904,
#   0.5012562870979309,
#   0.5087939500808716,
#   0.5427135825157166,
#   0.5339195728302002,
#   0.5389447212219238,
#   0.5351758599281311,
#   0.55402010679245,
#   0.5653266310691833,
#   0.5552763938903809,
#   0.5653266310691833,
#   0.5879396796226501,
#   0.6080402135848999,
#   0.589195966720581,
#   0.5917085409164429,
#   0.5979899764060974,
#   0.6017587780952454,
#   0.6042713522911072,
#   0.6143215894699097,
#   0.623115599155426,
#   0.6155778765678406,
#   0.6243718862533569,
#   0.6118090748786926,
#   0.623115599155426,
#   0.6155778765678406,
#   0.6306532621383667,
#   0.6168341636657715,
#   0.6118090748786926,
#   0.6168341636657715,
#   0.6092965006828308,
#   0.6206030249595642,
#   0.6130653023719788,
#   0.6080402135848999,
#   0.6356784105300903,
#   0.6080402135848999,
#   0.6118090748786926,
#   0.6331658363342285,
#   0.6180904507637024,
#   0.6180904507637024,
#   0.6017587780952454,
#   0.5967336893081665,
#   0.6193467378616333,
#   0.6005024909973145,
#   0.5967336893081665,
#   0.606783926486969,
#   0.6092965006828308,
#   0.6042713522911072,
#   0.6319095492362976],
#  'val_loss': [0.6963032484054565,
#   0.7091794013977051,
#   0.7130323648452759,
#   0.7097833156585693,
#   0.7294103503227234,
#   0.720085620880127,
#   0.7185202240943909,
#   0.7220848202705383,
#   0.7366194128990173,
#   0.7503100037574768,
#   0.770528256893158,
#   0.7887197732925415,
#   0.8272541165351868,
#   0.8739174008369446,
#   0.9170935153961182,
#   0.9605421423912048,
#   1.0657477378845215,
#   1.1212737560272217,
#   1.1498275995254517,
#   1.2285619974136353,
#   1.3026100397109985,
#   1.3737884759902954,
#   1.2645978927612305,
#   1.4819786548614502,
#   1.5075603723526,
#   1.4860846996307373,
#   1.7036049365997314,
#   1.778040885925293,
#   1.5678211450576782,
#   1.7304798364639282,
#   1.758717656135559,
#   1.7621252536773682,
#   1.8241167068481445,
#   1.4864574670791626,
#   1.9346590042114258,
#   1.9330432415008545,
#   1.9144394397735596,
#   2.1295175552368164,
#   1.9868301153182983,
#   1.8875067234039307,
#   2.143218755722046,
#   2.2967352867126465,
#   2.043368339538574,
#   1.9387180805206299,
#   2.222083568572998,
#   2.017577648162842,
#   2.151278018951416,
#   1.9822616577148438,
#   2.042954921722412,
#   2.029205083847046]}

# %%
#plot the best model
model_history = model_histories[3]
epochs = len(model_history.history['accuracy'])
train_accuracy = model_history.history['accuracy']
valid_accuracy = model_history.history['val_accuracy']
train_loss = model_history.history['loss']
valid_loss = model_history.history['val_loss']

fig, (accuracy, loss) = plt.subplots(1, 2, sharex=True, sharey=False)
fig.set_size_inches(12,4 )
accuracy.plot(range(1, epochs+1), valid_accuracy) 
accuracy.plot(range(1, epochs+1), train_accuracy)  
accuracy.set_ylabel('accuracy')
accuracy.set_xlabel('epoch')
accuracy.legend(['validation','train'], loc='upper left')
accuracy.set_title('Train and Validation Accuracy')

loss.plot(range(1, epochs+1), valid_loss)
loss.plot(range(1, epochs+1), train_loss)
loss.set_ylabel('loss')
loss.set_xlabel('epoch')
loss.legend(['validation', 'train'], loc='upper left')
loss.set_title('Train and Validation Loss')

plt.show()

# %%
def plot_training_history(model_histories):
    fig, ax = plt.subplots(1, 2, figsize=(20, 10))
    for model_history in model_histories:
        ax[0].plot(model_history.history['loss'], label='training loss')
        ax[0].plot(model_history.history['val_loss'], label='validation loss')
        ax[0].set_title('Loss')
        ax[0].set_xlabel('Epochs')
        ax[0].set_ylabel('Loss')
        ax[0].legend()

        ax[1].plot(model_history.history['accuracy'], label='training accuracy')
        ax[1].plot(model_history.history['val_accuracy'], label='validation accuracy')
        ax[1].set_title('Accuracy')
        ax[1].set_xlabel('Epochs')
        ax[1].set_ylabel('Accuracy')
        ax[1].legend()
    plt.show()

# %%
plot_training_history(model_histories)

# %%
test_images = []
test_labels = []
for images, labels in test_ds.as_numpy_iterator():
    test_images.extend(images)
    test_labels.extend(labels)
test_images = np.array(test_images).astype('float32')/255
test_labels = np.array(test_labels).astype('int')
# Out:
# 2024-03-19 06:26:23.597168: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
model = (model_histories[2].model)
model.evaluate(test_images, test_labels)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 328ms/step - accuracy: 0.5518 - loss: 2.3860
# [2.431056022644043, 0.5443786978721619]
