# %% [markdown]
# ## This notebook will:
# * Import libraries
# * Set global parameters
# * Check the training directory for non-jpg images and remove any that it finds
# * Load the images from a binary classification folder structure into a 3 datasets
# * Combine the datasets and convert to numpy arrays to work with sklearn functions
# * Split the data into Test / Train sets
# * Display a random training image
# * Define a model and generate a summary
# * Train the model using a validation split
# * Plot the model's training history (validation, train loss and accuracy)
# * Evaluate the model agianst the Test set

# %%
from os import path, makedirs, walk,listdir, remove
import pandas as pd
from shutil import copyfile
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Input, Rescaling, RandomFlip, RandomRotation, RandomZoom, RandomContrast
from keras.backend import clear_session
from keras.utils import image_dataset_from_directory, split_dataset
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from keras.metrics import BinaryAccuracy, Precision, Recall, F1Score, TrueNegatives, TruePositives, FalseNegatives, FalsePositives
from keras.callbacks import EarlyStopping
from random import choice

# %%
DATASET_NAMES = ('train','valid','test')
CLASS_DIRECTORY_NAMES = ('class_fracture','class_no_fracture')
DATASET_DIRECTORY = 'dataset'
TOP_DIRECTORY_CLASSIFIFICATIONS = path.join(DATASET_DIRECTORY ,'categorised_images')
AUGMENTATION_LAYERS = [RandomFlip("horizontal"), RandomRotation(0.2), RandomZoom(0.2), RandomContrast(0.2)]

#Hyperparameters
OPTIMIZER = Adam
LEARNING_RATE = 0.0001
LOSS_FUNCTION = BinaryCrossentropy
METRICS = [BinaryAccuracy(name='accuracy'), Precision(name='precision'), Recall(name='recall'), F1Score(name='f1'), TrueNegatives(name='tn'), TruePositives(name='tp'), FalseNegatives(name='fn'), FalsePositives(name='fp')]
EPOCHS = 50
BATCH_SIZE = 10
VERBOSE = 1
REGULARIZER=None
VALIDATION_SPLIT = 0.2
INPUT_SHAPE = (256,256,1)
# Out:
# 2024-03-26 15:25:03.677335: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2024-03-26 15:25:03.677363: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-03-26 15:25:03.677369: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-03-26 15:25:03.677591: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-03-26 15:25:03.677609: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#remove any non-jpg files in the directories
def find_and_remove_non_jpg_files(a_folder_path):
    #removes any non-jpg files in the provided directory
    num_skipped = 0
    for fname in listdir(a_folder_path):
        fpath = path.join(a_folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = b"JFIF" in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            # Delete corrupted image
            print('removing non-image file: ' + fpath)
            remove(fpath)

    print(f"Deleted {num_skipped} files.")

# %%
#remove any non-processable files from the image directories
folders_checked = 0
for dataset_name in DATASET_NAMES:
    for class_dir_name in CLASS_DIRECTORY_NAMES:
        folder_path = path.join(TOP_DIRECTORY_CLASSIFIFICATIONS, dataset_name,class_dir_name)
        print('checking folder: '+folder_path)
        find_and_remove_non_jpg_files(folder_path)
        folders_checked +=1
print('checked', folders_checked, 'folders')
# Out:
# checking folder: dataset/categorised_images/train/class_fracture
# Deleted 0 files.
# checking folder: dataset/categorised_images/train/class_no_fracture
# Deleted 0 files.
# checking folder: dataset/categorised_images/valid/class_fracture
# Deleted 0 files.
# checking folder: dataset/categorised_images/valid/class_no_fracture
# Deleted 0 files.
# checking folder: dataset/categorised_images/test/class_fracture
# Deleted 0 files.
# checking folder: dataset/categorised_images/test/class_no_fracture
# Deleted 0 files.
# checked 6 folders

# %%
def load_images(dataset_name):
    
    return image_dataset_from_directory(
    directory= path.join(TOP_DIRECTORY_CLASSIFIFICATIONS, dataset_name),
    labels='inferred',
    label_mode="binary",
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    image_size=(256, 256),
    shuffle=True,
    seed=42,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False
)

# %%
#Load the images into datasets
train_ds= load_images('train')
test_ds = load_images('test')
valid_ds = load_images('valid')
print('train_ds', train_ds.cardinality())
print('test_ds', test_ds.cardinality())
print('valid_ds', valid_ds.cardinality())

#create a combined dataset so the data can be shuffled and then split into training and test sets
combined_ds = train_ds.concatenate(valid_ds).concatenate(test_ds)
print('combined_ds', combined_ds.cardinality())
# Out:
# Found 3630 files belonging to 2 classes.
# Found 169 files belonging to 2 classes.
# Found 348 files belonging to 2 classes.
# train_ds tf.Tensor(363, shape=(), dtype=int64)
# test_ds tf.Tensor(17, shape=(), dtype=int64)
# valid_ds tf.Tensor(35, shape=(), dtype=int64)
# combined_ds tf.Tensor(415, shape=(), dtype=int64)

# %%
combined_images = []
combined_labels = []
for images, labels in combined_ds.as_numpy_iterator():
    combined_images.extend(images)
    combined_labels.extend(labels)
combined_images = np.array(combined_images)
combined_labels = np.array(combined_labels)

X_train, X_test, y_train, y_test = train_test_split(combined_images, combined_labels, test_size=0.2, random_state=42)
print('X_train', X_train.shape)
print('X_test', X_test.shape)
print('y_train', y_train.shape)
print('y_test', y_test.shape)
# Out:
# 2024-03-26 15:25:19.274593: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# X_train (3317, 256, 256, 1)
# X_test (830, 256, 256, 1)
# y_train (3317, 1)
# y_test (830, 1)

# %%
random_training_image = choice(X_train)
plt.imshow(random_training_image, cmap='gray')
plt.show()

# %%
def create_model(input_shape):

    #create a Sequential  model
    model = Sequential()
    #Add the layers
    model.add(Input(input_shape))
    #add augmentation layers
    for layer in AUGMENTATION_LAYERS:
        model.add(layer)
    model.add(Rescaling(1.0 / 255))
    #Add 2 convolutional layers paired with max pooling layers
    model.add(Conv2D(filters = 64, kernel_size = (3,3), strides = (1,1), padding = 'valid', activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Conv2D(filters = 128, kernel_size = (3,3), strides = (1,1), padding = 'valid', activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Conv2D(filters = 256, kernel_size = (3,3), strides = (1,1), padding = 'valid', activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
    #Flatten the output so that it can be processed as a Vector by the subsequent Dense layer
    model.add(Flatten())

    #add a fully connected layer with  64 neurons and a relu activation function outut shape = 64
    model.add(Dense(256, kernel_regularizer=REGULARIZER, activation='relu'))
    #add output layer with a single neuron and a sigmoind activation to represent the binary classification
    model.add(Dense(1, kernel_regularizer=REGULARIZER, activation='sigmoid'))

    return model

# %%
model = create_model(INPUT_SHAPE)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 256, 256, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 256, 256, 1)    │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom (RandomZoom)        │ (None, 256, 256, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast                 │ (None, 256, 256, 1)    │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 256, 256, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 254, 254, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 230400)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    58,982,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 59,352,577 (226.41 MB)
#  Trainable params: 59,352,577 (226.41 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def train_model(X_train, y_train):
    
    callbacks = [EarlyStopping(monitor='val_accuracy', patience=5, verbose=VERBOSE, restore_best_weights=True)]
    
    model = create_model(INPUT_SHAPE)
    model.compile(optimizer=OPTIMIZER(LEARNING_RATE), loss=LOSS_FUNCTION(), metrics=METRICS)
    model_history = model.fit(
                            X_train, y_train,
                            epochs=EPOCHS,
                            batch_size=BATCH_SIZE,
                            validation_split=VALIDATION_SPLIT,
                            verbose=VERBOSE,
                            callbacks=callbacks)
    clear_session()

    return (model, model_history)

# %%
model, model_history = train_model(X_train, y_train)
# Out:
# Epoch 1/50
# 2024-03-26 15:26:11.407691: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 35s 125ms/step - accuracy: 0.5153 - f1: 0.6641 - fn: 211.7978 - fp: 440.2921 - loss: 0.7008 - precision: 0.5106 - recall: 0.6546 - tn: 235.1835 - tp: 452.6367 - val_accuracy: 0.5512 - val_f1: 0.6942 - val_fn: 22.0000 - val_fp: 276.0000 - val_loss: 0.6875 - val_precision: 0.5453 - val_recall: 0.9377 - val_tn: 35.0000 - val_tp: 331.0000
# Epoch 2/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.5173 - f1: 0.6679 - fn: 112.7191 - fp: 524.8764 - loss: 0.6919 - precision: 0.5116 - recall: 0.8642 - tn: 143.2022 - tp: 559.1124 - val_accuracy: 0.5497 - val_f1: 0.6942 - val_fn: 56.0000 - val_fp: 243.0000 - val_loss: 0.6781 - val_precision: 0.5500 - val_recall: 0.8414 - val_tn: 68.0000 - val_tp: 297.0000
# Epoch 3/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 118ms/step - accuracy: 0.5182 - f1: 0.6566 - fn: 300.6891 - fp: 343.8090 - loss: 0.6897 - precision: 0.5069 - recall: 0.5706 - tn: 334.1685 - tp: 361.2434 - val_accuracy: 0.5286 - val_f1: 0.6942 - val_fn: 29.0000 - val_fp: 284.0000 - val_loss: 0.6801 - val_precision: 0.5329 - val_recall: 0.9178 - val_tn: 27.0000 - val_tp: 324.0000
# Epoch 4/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 118ms/step - accuracy: 0.4934 - f1: 0.6533 - fn: 247.4419 - fp: 417.3745 - loss: 0.6886 - precision: 0.4869 - recall: 0.6673 - tn: 262.6966 - tp: 412.3970 - val_accuracy: 0.5512 - val_f1: 0.6942 - val_fn: 169.0000 - val_fp: 129.0000 - val_loss: 0.6804 - val_precision: 0.5879 - val_recall: 0.5212 - val_tn: 182.0000 - val_tp: 184.0000
# Epoch 5/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 118ms/step - accuracy: 0.5311 - f1: 0.6639 - fn: 411.1273 - fp: 213.4607 - loss: 0.6843 - precision: 0.5404 - recall: 0.3695 - tn: 457.0262 - tp: 258.2959 - val_accuracy: 0.5497 - val_f1: 0.6942 - val_fn: 166.0000 - val_fp: 133.0000 - val_loss: 0.6766 - val_precision: 0.5844 - val_recall: 0.5297 - val_tn: 178.0000 - val_tp: 187.0000
# Epoch 6/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 118ms/step - accuracy: 0.5326 - f1: 0.6557 - fn: 404.1236 - fp: 210.1685 - loss: 0.6873 - precision: 0.5308 - recall: 0.3465 - tn: 473.6779 - tp: 251.9401 - val_accuracy: 0.5587 - val_f1: 0.6942 - val_fn: 84.0000 - val_fp: 209.0000 - val_loss: 0.6702 - val_precision: 0.5628 - val_recall: 0.7620 - val_tn: 102.0000 - val_tp: 269.0000
# Epoch 7/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 119ms/step - accuracy: 0.5551 - f1: 0.6610 - fn: 322.0300 - fp: 272.5880 - loss: 0.6813 - precision: 0.5498 - recall: 0.5398 - tn: 408.3596 - tp: 336.9326 - val_accuracy: 0.5572 - val_f1: 0.6942 - val_fn: 102.0000 - val_fp: 192.0000 - val_loss: 0.6698 - val_precision: 0.5666 - val_recall: 0.7110 - val_tn: 119.0000 - val_tp: 251.0000
# Epoch 8/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 118ms/step - accuracy: 0.5532 - f1: 0.6756 - fn: 300.0412 - fp: 292.5843 - loss: 0.6819 - precision: 0.5616 - recall: 0.5705 - tn: 368.6929 - tp: 378.5918 - val_accuracy: 0.5497 - val_f1: 0.6942 - val_fn: 235.0000 - val_fp: 64.0000 - val_loss: 0.6864 - val_precision: 0.6484 - val_recall: 0.3343 - val_tn: 247.0000 - val_tp: 118.0000
# Epoch 9/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.5489 - f1: 0.6837 - fn: 308.7154 - fp: 290.8614 - loss: 0.6766 - precision: 0.5686 - recall: 0.5458 - tn: 360.4082 - tp: 379.9251 - val_accuracy: 0.5482 - val_f1: 0.6942 - val_fn: 221.0000 - val_fp: 79.0000 - val_loss: 0.6708 - val_precision: 0.6256 - val_recall: 0.3739 - val_tn: 232.0000 - val_tp: 132.0000
# Epoch 10/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.5539 - f1: 0.6827 - fn: 300.3895 - fp: 283.5543 - loss: 0.6800 - precision: 0.5704 - recall: 0.5875 - tn: 378.9626 - tp: 377.0038 - val_accuracy: 0.5587 - val_f1: 0.6942 - val_fn: 156.0000 - val_fp: 137.0000 - val_loss: 0.6712 - val_precision: 0.5898 - val_recall: 0.5581 - val_tn: 174.0000 - val_tp: 197.0000
# Epoch 11/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.5590 - f1: 0.6735 - fn: 333.9663 - fp: 262.8802 - loss: 0.6735 - precision: 0.5684 - recall: 0.5391 - tn: 407.1423 - tp: 335.9214 - val_accuracy: 0.5617 - val_f1: 0.6942 - val_fn: 173.0000 - val_fp: 118.0000 - val_loss: 0.6679 - val_precision: 0.6040 - val_recall: 0.5099 - val_tn: 193.0000 - val_tp: 180.0000
# Epoch 12/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.5688 - f1: 0.6665 - fn: 352.7828 - fp: 230.2622 - loss: 0.6755 - precision: 0.5841 - recall: 0.4749 - tn: 446.6068 - tp: 310.2584 - val_accuracy: 0.5663 - val_f1: 0.6942 - val_fn: 164.0000 - val_fp: 124.0000 - val_loss: 0.6750 - val_precision: 0.6038 - val_recall: 0.5354 - val_tn: 187.0000 - val_tp: 189.0000
# Epoch 13/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 118ms/step - accuracy: 0.5883 - f1: 0.6799 - fn: 318.2434 - fp: 248.6105 - loss: 0.6680 - precision: 0.6069 - recall: 0.5591 - tn: 409.1948 - tp: 363.8614 - val_accuracy: 0.5497 - val_f1: 0.6942 - val_fn: 209.0000 - val_fp: 90.0000 - val_loss: 0.6898 - val_precision: 0.6154 - val_recall: 0.4079 - val_tn: 221.0000 - val_tp: 144.0000
# Epoch 14/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.5713 - f1: 0.6626 - fn: 378.1423 - fp: 191.1498 - loss: 0.6667 - precision: 0.5960 - recall: 0.4043 - tn: 483.1049 - tp: 287.5131 - val_accuracy: 0.5783 - val_f1: 0.6942 - val_fn: 159.0000 - val_fp: 121.0000 - val_loss: 0.6835 - val_precision: 0.6159 - val_recall: 0.5496 - val_tn: 190.0000 - val_tp: 194.0000
# Epoch 15/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 33s 121ms/step - accuracy: 0.5859 - f1: 0.6505 - fn: 340.0000 - fp: 218.3858 - loss: 0.6671 - precision: 0.5868 - recall: 0.4764 - tn: 467.0112 - tp: 314.5131 - val_accuracy: 0.5587 - val_f1: 0.6942 - val_fn: 149.0000 - val_fp: 144.0000 - val_loss: 0.6628 - val_precision: 0.5862 - val_recall: 0.5779 - val_tn: 167.0000 - val_tp: 204.0000
# Epoch 16/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.5781 - f1: 0.6638 - fn: 345.1536 - fp: 208.6217 - loss: 0.6653 - precision: 0.5953 - recall: 0.4837 - tn: 467.6742 - tp: 318.4607 - val_accuracy: 0.5843 - val_f1: 0.6942 - val_fn: 146.0000 - val_fp: 130.0000 - val_loss: 0.6557 - val_precision: 0.6142 - val_recall: 0.5864 - val_tn: 181.0000 - val_tp: 207.0000
# Epoch 17/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 119ms/step - accuracy: 0.6007 - f1: 0.6557 - fn: 326.0524 - fp: 217.7378 - loss: 0.6524 - precision: 0.6065 - recall: 0.5179 - tn: 461.8614 - tp: 334.2584 - val_accuracy: 0.5889 - val_f1: 0.6942 - val_fn: 158.0000 - val_fp: 115.0000 - val_loss: 0.6628 - val_precision: 0.6290 - val_recall: 0.5524 - val_tn: 196.0000 - val_tp: 195.0000
# Epoch 18/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.5895 - f1: 0.6643 - fn: 350.3970 - fp: 200.1461 - loss: 0.6640 - precision: 0.6097 - recall: 0.4840 - tn: 475.8502 - tp: 313.5168 - val_accuracy: 0.5738 - val_f1: 0.6942 - val_fn: 164.0000 - val_fp: 119.0000 - val_loss: 0.6640 - val_precision: 0.6136 - val_recall: 0.5354 - val_tn: 192.0000 - val_tp: 189.0000
# Epoch 19/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.5926 - f1: 0.6652 - fn: 341.4981 - fp: 201.8839 - loss: 0.6561 - precision: 0.6139 - recall: 0.4927 - tn: 466.2921 - tp: 330.2360 - val_accuracy: 0.6039 - val_f1: 0.6942 - val_fn: 185.0000 - val_fp: 78.0000 - val_loss: 0.6612 - val_precision: 0.6829 - val_recall: 0.4759 - val_tn: 233.0000 - val_tp: 168.0000
# Epoch 20/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 119ms/step - accuracy: 0.5970 - f1: 0.6570 - fn: 334.2734 - fp: 201.9438 - loss: 0.6543 - precision: 0.6095 - recall: 0.4905 - tn: 476.2959 - tp: 327.3970 - val_accuracy: 0.5949 - val_f1: 0.6942 - val_fn: 184.0000 - val_fp: 85.0000 - val_loss: 0.6570 - val_precision: 0.6654 - val_recall: 0.4788 - val_tn: 226.0000 - val_tp: 169.0000
# Epoch 21/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 119ms/step - accuracy: 0.6199 - f1: 0.6763 - fn: 288.5506 - fp: 224.8052 - loss: 0.6474 - precision: 0.6407 - recall: 0.5832 - tn: 439.0862 - tp: 387.4682 - val_accuracy: 0.6069 - val_f1: 0.6942 - val_fn: 178.0000 - val_fp: 83.0000 - val_loss: 0.6575 - val_precision: 0.6783 - val_recall: 0.4958 - val_tn: 228.0000 - val_tp: 175.0000
# Epoch 22/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 118ms/step - accuracy: 0.6085 - f1: 0.6552 - fn: 344.8352 - fp: 184.0936 - loss: 0.6421 - precision: 0.6369 - recall: 0.4599 - tn: 496.8577 - tp: 314.1236 - val_accuracy: 0.5964 - val_f1: 0.6942 - val_fn: 109.0000 - val_fp: 159.0000 - val_loss: 0.6707 - val_precision: 0.6055 - val_recall: 0.6912 - val_tn: 152.0000 - val_tp: 244.0000
# Epoch 23/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 119ms/step - accuracy: 0.6258 - f1: 0.6638 - fn: 297.7715 - fp: 214.0974 - loss: 0.6364 - precision: 0.6368 - recall: 0.5737 - tn: 459.5356 - tp: 368.5056 - val_accuracy: 0.6114 - val_f1: 0.6942 - val_fn: 159.0000 - val_fp: 99.0000 - val_loss: 0.6533 - val_precision: 0.6621 - val_recall: 0.5496 - val_tn: 212.0000 - val_tp: 194.0000
# Epoch 24/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 119ms/step - accuracy: 0.6051 - f1: 0.6664 - fn: 301.9813 - fp: 214.0712 - loss: 0.6444 - precision: 0.6245 - recall: 0.5266 - tn: 461.9550 - tp: 361.9026 - val_accuracy: 0.6446 - val_f1: 0.6942 - val_fn: 117.0000 - val_fp: 119.0000 - val_loss: 0.6375 - val_precision: 0.6648 - val_recall: 0.6686 - val_tn: 192.0000 - val_tp: 236.0000
# Epoch 25/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 31s 118ms/step - accuracy: 0.6466 - f1: 0.6583 - fn: 281.1086 - fp: 207.3296 - loss: 0.6247 - precision: 0.6512 - recall: 0.6007 - tn: 474.2060 - tp: 377.2659 - val_accuracy: 0.6130 - val_f1: 0.6942 - val_fn: 119.0000 - val_fp: 138.0000 - val_loss: 0.6418 - val_precision: 0.6290 - val_recall: 0.6629 - val_tn: 173.0000 - val_tp: 234.0000
# Epoch 26/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 121ms/step - accuracy: 0.6240 - f1: 0.6657 - fn: 292.2434 - fp: 214.6067 - loss: 0.6379 - precision: 0.6352 - recall: 0.5778 - tn: 453.2060 - tp: 379.8539 - val_accuracy: 0.6130 - val_f1: 0.6942 - val_fn: 140.0000 - val_fp: 117.0000 - val_loss: 0.6329 - val_precision: 0.6455 - val_recall: 0.6034 - val_tn: 194.0000 - val_tp: 213.0000
# Epoch 27/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 119ms/step - accuracy: 0.6395 - f1: 0.6463 - fn: 293.5168 - fp: 201.9401 - loss: 0.6240 - precision: 0.6404 - recall: 0.5608 - tn: 485.8502 - tp: 358.6030 - val_accuracy: 0.6099 - val_f1: 0.6942 - val_fn: 122.0000 - val_fp: 137.0000 - val_loss: 0.6338 - val_precision: 0.6277 - val_recall: 0.6544 - val_tn: 174.0000 - val_tp: 231.0000
# Epoch 28/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 121ms/step - accuracy: 0.6276 - f1: 0.6633 - fn: 271.6704 - fp: 226.2322 - loss: 0.6417 - precision: 0.6308 - recall: 0.6029 - tn: 447.4869 - tp: 394.5206 - val_accuracy: 0.6084 - val_f1: 0.6942 - val_fn: 154.0000 - val_fp: 106.0000 - val_loss: 0.6430 - val_precision: 0.6525 - val_recall: 0.5637 - val_tn: 205.0000 - val_tp: 199.0000
# Epoch 29/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 121ms/step - accuracy: 0.6431 - f1: 0.6658 - fn: 268.6217 - fp: 208.0187 - loss: 0.6252 - precision: 0.6569 - recall: 0.5966 - tn: 463.1348 - tp: 400.1348 - val_accuracy: 0.6476 - val_f1: 0.6942 - val_fn: 166.0000 - val_fp: 68.0000 - val_loss: 0.6371 - val_precision: 0.7333 - val_recall: 0.5297 - val_tn: 243.0000 - val_tp: 187.0000
# Epoch 30/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 121ms/step - accuracy: 0.6514 - f1: 0.6687 - fn: 264.4981 - fp: 202.4082 - loss: 0.6284 - precision: 0.6742 - recall: 0.5960 - tn: 468.7753 - tp: 404.2285 - val_accuracy: 0.6310 - val_f1: 0.6942 - val_fn: 129.0000 - val_fp: 116.0000 - val_loss: 0.6263 - val_precision: 0.6588 - val_recall: 0.6346 - val_tn: 195.0000 - val_tp: 224.0000
# Epoch 31/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.6487 - f1: 0.6679 - fn: 249.1199 - fp: 220.2734 - loss: 0.6132 - precision: 0.6548 - recall: 0.6346 - tn: 447.0000 - tp: 423.5168 - val_accuracy: 0.6642 - val_f1: 0.6942 - val_fn: 153.0000 - val_fp: 70.0000 - val_loss: 0.6252 - val_precision: 0.7407 - val_recall: 0.5666 - val_tn: 241.0000 - val_tp: 200.0000
# Epoch 32/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.6512 - f1: 0.6536 - fn: 270.0562 - fp: 199.3596 - loss: 0.6136 - precision: 0.6602 - recall: 0.5806 - tn: 486.7753 - tp: 383.7191 - val_accuracy: 0.6491 - val_f1: 0.6942 - val_fn: 89.0000 - val_fp: 144.0000 - val_loss: 0.6255 - val_precision: 0.6471 - val_recall: 0.7479 - val_tn: 167.0000 - val_tp: 264.0000
# Epoch 33/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 122ms/step - accuracy: 0.6556 - f1: 0.6758 - fn: 234.9513 - fp: 229.4906 - loss: 0.6013 - precision: 0.6596 - recall: 0.6690 - tn: 440.0562 - tp: 435.4120 - val_accuracy: 0.6717 - val_f1: 0.6942 - val_fn: 91.0000 - val_fp: 127.0000 - val_loss: 0.6074 - val_precision: 0.6735 - val_recall: 0.7422 - val_tn: 184.0000 - val_tp: 262.0000
# Epoch 34/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 121ms/step - accuracy: 0.6629 - f1: 0.6502 - fn: 250.4120 - fp: 210.5880 - loss: 0.5989 - precision: 0.6548 - recall: 0.6408 - tn: 472.0374 - tp: 406.8727 - val_accuracy: 0.6416 - val_f1: 0.6942 - val_fn: 145.0000 - val_fp: 93.0000 - val_loss: 0.6345 - val_precision: 0.6910 - val_recall: 0.5892 - val_tn: 218.0000 - val_tp: 208.0000
# Epoch 35/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 121ms/step - accuracy: 0.6797 - f1: 0.6576 - fn: 236.7790 - fp: 200.3408 - loss: 0.5939 - precision: 0.6870 - recall: 0.6380 - tn: 479.8390 - tp: 422.9513 - val_accuracy: 0.6295 - val_f1: 0.6942 - val_fn: 113.0000 - val_fp: 133.0000 - val_loss: 0.6158 - val_precision: 0.6434 - val_recall: 0.6799 - val_tn: 178.0000 - val_tp: 240.0000
# Epoch 36/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.6743 - f1: 0.6644 - fn: 241.7715 - fp: 202.6330 - loss: 0.5905 - precision: 0.6870 - recall: 0.6370 - tn: 472.3558 - tp: 423.1498 - val_accuracy: 0.6702 - val_f1: 0.6942 - val_fn: 81.0000 - val_fp: 138.0000 - val_loss: 0.6091 - val_precision: 0.6634 - val_recall: 0.7705 - val_tn: 173.0000 - val_tp: 272.0000
# Epoch 37/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 119ms/step - accuracy: 0.6842 - f1: 0.6604 - fn: 218.8202 - fp: 207.6592 - loss: 0.5975 - precision: 0.6760 - recall: 0.6914 - tn: 470.2734 - tp: 443.1573 - val_accuracy: 0.6702 - val_f1: 0.6942 - val_fn: 97.0000 - val_fp: 122.0000 - val_loss: 0.6117 - val_precision: 0.6772 - val_recall: 0.7252 - val_tn: 189.0000 - val_tp: 256.0000
# Epoch 38/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 32s 120ms/step - accuracy: 0.6569 - f1: 0.6795 - fn: 229.4007 - fp: 224.6442 - loss: 0.5966 - precision: 0.6650 - recall: 0.6718 - tn: 436.3296 - tp: 449.5356 - val_accuracy: 0.6581 - val_f1: 0.6942 - val_fn: 151.0000 - val_fp: 76.0000 - val_loss: 0.6206 - val_precision: 0.7266 - val_recall: 0.5722 - val_tn: 235.0000 - val_tp: 202.0000
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 33.

# %%
#plot the model accuracy and loss]
epochs = len(model_history.history['accuracy'])
train_accuracy = model_history.history['accuracy']
valid_accuracy = model_history.history['val_accuracy']
train_loss = model_history.history['loss']
valid_loss = model_history.history['val_loss']

fig, (accuracy, loss) = plt.subplots(1, 2, sharex=True, sharey=False)
fig.set_size_inches(12,4 )
accuracy.plot(range(1, epochs+1), valid_accuracy) 
accuracy.plot(range(1, epochs+1), train_accuracy)  
accuracy.set_ylabel('accuracy')
accuracy.set_xlabel('epoch')
accuracy.legend(['validation','train'], loc='upper left')
accuracy.set_title('Train and Validation Accuracy')

loss.plot(range(1, epochs+1), valid_loss)
loss.plot(range(1, epochs+1), train_loss)
loss.set_ylabel('loss')
loss.set_xlabel('epoch')
loss.legend(['validation', 'train'], loc='upper left')
loss.set_title('Train and Validation Loss')

plt.show()

# %%
results  = model.evaluate(X_test, y_test)
print('accuracy', results[1])
print('loss', results[0])
print('precision', results[2])
print('recall', results[3])
print('f1', results[4])
print('tn', results[5])
print('tp', results[6])
print('fn', results[7])
print('fp', results[8])
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.6284 - f1: 0.6773 - fn: 63.4444 - fp: 106.4815 - loss: 0.6282 - precision: 0.6171 - recall: 0.7206 - tn: 117.6296 - tp: 159.1111
# accuracy 0.6240963935852051
# loss 0.6265997290611267
# precision 0.6645212769508362
# recall 117.0
# f1 195.0
# tn 0.6028513312339783
# tp 0.7167070508003235
# fn 222.0
# fp 296.0

# %%
predictions = model.predict(X_test)
binary_predictions = np.where(predictions > 0.5, 1, 0)
binary_predictions
matrix = confusion_matrix(y_test, binary_predictions)
ConfusionMatrixDisplay(matrix, display_labels=['no fracture', 'fracture']).plot()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step

# %%
import datetime
print("Last modified: ", datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S") + "\n")
# Out:
# Last modified:  26/03/2024 15:49:13
